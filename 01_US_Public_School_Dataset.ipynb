# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### US Public School Datasets for year 2020-21

# %% [markdown]
# - [Public school characteristics dataset](https://data-nces.opendata.arcgis.com/datasets/e3cbd4087f144ec5ac3b31094ec84199_0/explore?location=35.265505%2C-96.401190%2C4.84)
# - [Public school Retention Dataset](https://civilrightsdata.ed.gov/data)

# %% [markdown]
# ### Reading CSV'S

# %%
#Reading csv's into dataframe

df1 = pd.read_csv('data/Public_School_Characteristics_2020-21.csv')
df2 = pd.read_csv('data/Retention.csv')

# %% [markdown]
# ### Cleaning df1 (School Characteristic dataset)

# %%
#Let's look at first five rows of school characteristics dataset
df1.head(5)
# Out:
#            X        Y  OBJECTID      NCESSCH   SURVYEAR STABR   LEAID
# 0 -86.206200  34.2602         1  10000500870  2020-2021    AL  100005  \
# 1 -86.204900  34.2622         2  10000500871  2020-2021    AL  100005
# 2 -86.220100  34.2733         3  10000500879  2020-2021    AL  100005
# 3 -86.221806  34.2527         4  10000500889  2020-2021    AL  100005
# 4 -86.193300  34.2898         5  10000501616  2020-2021    AL  100005
#
#   ST_LEAID          LEA_NAME                           SCH_NAME  ...  HIALF
# 0   AL-101  Albertville City          Albertville Middle School  ...  230.0  \
# 1   AL-101  Albertville City            Albertville High School  ...  371.0
# 2   AL-101  Albertville City    Albertville Intermediate School  ...  253.0
# 3   AL-101  Albertville City      Albertville Elementary School  ...  237.0
# 4   AL-101  Albertville City  Albertville Kindergarten and PreK  ...  137.0
#
#       HI TRALM TRALF    TR  WHALM  WHALF     WH   LATCOD     LONCOD
# 0  469.0  19.0  10.0  29.0  187.0  184.0  371.0  34.2602 -86.206200
# 1  785.0  17.0  21.0  38.0  368.0  338.0  706.0  34.2622 -86.204900
# 2  481.0  17.0  12.0  29.0  177.0  168.0  345.0  34.2733 -86.220100
# 3  497.0   7.0   8.0  15.0  180.0  160.0  340.0  34.2527 -86.221806
# 4  288.0   6.0   7.0  13.0  108.0  108.0  216.0  34.2898 -86.193300
#
# [5 rows x 79 columns]

# %%
# Converting NCESSCH columns into string from int
df1['NCESSCH'] = df1['NCESSCH'].astype(str)

# %%
# Filling NAN with 0
df1[['PK', 'G13', 'UG']] = df1[['PK', 'G13', 'UG']].fillna(0)

# %%
# Removing data for PK(Pre-Kindergarten), UG(Ungraded) and AE(Adult Education) from total enrollment (MEMBER) column
df1['MEMBER'] = df1['MEMBER'] - (df1['PK'] + df1['G13'] + df1['UG'])

# %%
# Calculating number of blank values in total enrollment (MEMBER) column
df1['MEMBER'].isna().sum()
# Out:
# 2071

# %%
# Cleaning rows with NAN value
df1.dropna(subset=['MEMBER'],inplace=True)

# %%
# Removing irrelevant columns from df1
df1_cols_to_remove = ['X','Y','OBJECTID','SURVYEAR','STABR','LEAID','ST_LEAID','LEA_NAME','SCH_NAME',
                     'LSTREET1','LSTREET2','LCITY','LSTATE','LZIP','LZIP4','PHONE','GSLO','GSHI',
                      'TITLEI','STATUS','SY_STATUS_TEXT','NMCNTY','FRELCH','REDLCH','PK','G13','UG','AE',
                      'TOTMENROL','TOTFENROL','TOTAL','AM','AS','BL','HP','HI','TR','WH']
df1.drop(columns=df1_cols_to_remove, inplace=True)

# %%
df1.shape
# Out:
# (98651, 41)

# %%
# Replacing missing and not available codes with NAN values
df1.replace([-1,-2], np.nan, inplace=True)

# %%
# Cleaning rows with NAN value
df1.dropna(subset=['STUTERATIO'],inplace=True)

# %%
df1.shape
# Out:
# (89965, 41)

# %% [markdown]
# ### Cleaning df2 (Retention dataset)

# %%
#Let's look at first five rows of school characteristics dataset
df2.head(5)
# Out:
#   LEA_STATE LEA_STATE_NAME   LEAID                LEA_NAME  SCHID
# 0        AL        Alabama  100002  Alabama Youth Services   1705  \
# 1        AL        Alabama  100002  Alabama Youth Services   1706
# 2        AL        Alabama  100002  Alabama Youth Services  99995
# 3        AL        Alabama  100005        Albertville City    870
# 4        AL        Alabama  100005        Albertville City    871
#
#                         SCH_NAME     COMBOKEY   JJ SCH_RET_KG_IND
# 0  Wallace Sch - Mt Meigs Campus  10000201705  Yes             -9  \
# 1      Mcneel Sch - Vacca Campus  10000201706  Yes             -9
# 2                 Autauga Campus  10000299995  Yes             -9
# 3      Albertville Middle School  10000500870   No             -9
# 4        Albertville High School  10000500871   No             -9
#
#   SCH_RET_G01_IND  ... SCH_RET_G12_TR_M SCH_RET_G12_TR_F TOT_RET_G12_M
# 0              -9  ...                0                0             1  \
# 1              -9  ...               -9               -9            -9
# 2              -9  ...               -9               -9            -9
# 3              -9  ...               -9               -9            -9
# 4              -9  ...                1                0             8
#
#   TOT_RET_G12_F SCH_RET_G12_LEP_M SCH_RET_G12_LEP_F SCH_RET_G12_IDEA_M
# 0             0                 0                 0                  0  \
# 1            -9                -9                -9                 -9
# 2            -9                -9                -9                 -9
# 3            -9                -9                -9                 -9
# 4             4                 2                 0                  5
#
#   SCH_RET_G12_IDEA_F SCH_RET_G12_504_M SCH_RET_G12_504_F
# 0                  0                 0                 0
# 1                 -9                -9                -9
# 2                 -9                -9                -9
# 3                 -9                -9                -9
# 4                  3                 0                 0
#
# [5 rows x 307 columns]

# %%
# Renaming COMBOKEY column to NCESSCH to merge df1 and df2
df2.rename(columns = {'COMBOKEY':'NCESSCH'}, inplace = True)

# %%
# Converting NCESSCH columns into string from int
df2['NCESSCH'] = df2['NCESSCH'].astype(str)

# %%
# Removing irrelevant columns from df2
df2_cols_to_remove = ['LEA_STATE','LEAID','LEA_NAME','SCHID','SCH_NAME','JJ','SCH_RET_KG_IND',
                  'SCH_RET_G01_IND','SCH_RET_G02_IND','SCH_RET_G03_IND','SCH_RET_G04_IND',
                  'SCH_RET_G05_IND','SCH_RET_G06_IND','SCH_RET_G07_IND','SCH_RET_G08_IND',
                  'SCH_RET_G09_IND','SCH_RET_G10_IND','SCH_RET_G11_IND','SCH_RET_G12_IND']
df2.drop(columns=df2_cols_to_remove, inplace=True)

# %%
df2.shape
# Out:
# (97575, 288)

# %%
# Replacing suppressed data values with NAN values
df2.replace([-11], np.nan, inplace=True)

# %%
# Cleaning rows with NAN value
df2.dropna(inplace=True)

# %%
df2.shape
# Out:
# (95413, 288)

# %% [markdown]
# ### Merging df1(School Characteristics dataset) and df2(Retention dataset)

# %%
# Merging Retention dataset and public school characteristics dataset on NCESSCH 
merged_df = pd.merge(df1, df2, on=['NCESSCH'], how='inner')
merged_df.shape
# Out:
# (85233, 328)

# %%
# Replacing Not applicable values with Nan values
merged_df.replace([-9], np.nan, inplace=True)

# %%
# Getting all retention columns
ret_cols = merged_df.filter(like = 'SCH_RET_')
ret_cols
# Out:
#        SCH_RET_KG_HI_M  SCH_RET_KG_HI_F  SCH_RET_KG_AM_M  SCH_RET_KG_AM_F
# 0                  NaN              NaN              NaN              NaN  \
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                 11.0             12.0              1.0              0.0
# ...                ...              ...              ...              ...
# 85228              4.0              5.0              0.0              0.0
# 85229              5.0              2.0              0.0              0.0
# 85230              NaN              NaN              NaN              NaN
# 85231              1.0              0.0              0.0              0.0
# 85232              NaN              NaN              NaN              NaN
#
#        SCH_RET_KG_AS_M  SCH_RET_KG_AS_F  SCH_RET_KG_HP_M  SCH_RET_KG_HP_F
# 0                  NaN              NaN              NaN              NaN  \
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  0.0              0.0              0.0              0.0
# ...                ...              ...              ...              ...
# 85228              0.0              0.0              0.0              0.0
# 85229              0.0              0.0              0.0              0.0
# 85230              NaN              NaN              NaN              NaN
# 85231              0.0              0.0              0.0              0.0
# 85232              NaN              NaN              NaN              NaN
#
#        SCH_RET_KG_BL_M  SCH_RET_KG_BL_F  ...  SCH_RET_G12_WH_M
# 0                  NaN              NaN  ...               NaN  \
# 1                  NaN              NaN  ...               4.0
# 2                  NaN              NaN  ...               NaN
# 3                  NaN              NaN  ...               NaN
# 4                  0.0              1.0  ...               NaN
# ...                ...              ...  ...               ...
# 85228              0.0              0.0  ...               NaN
# 85229              0.0              0.0  ...               NaN
# 85230              NaN              NaN  ...               NaN
# 85231              0.0              0.0  ...               NaN
# 85232              NaN              NaN  ...               0.0
#
#        SCH_RET_G12_WH_F  SCH_RET_G12_TR_M  SCH_RET_G12_TR_F
# 0                   NaN               NaN               NaN  \
# 1                   3.0               1.0               0.0
# 2                   NaN               NaN               NaN
# 3                   NaN               NaN               NaN
# 4                   NaN               NaN               NaN
# ...                 ...               ...               ...
# 85228               NaN               NaN               NaN
# 85229               NaN               NaN               NaN
# 85230               NaN               NaN               NaN
# 85231               NaN               NaN               NaN
# 85232               0.0               0.0               0.0
#
#        SCH_RET_G12_LEP_M  SCH_RET_G12_LEP_F  SCH_RET_G12_IDEA_M
# 0                    NaN                NaN                 NaN  \
# 1                    2.0                0.0                 5.0
# 2                    NaN                NaN                 NaN
# 3                    NaN                NaN                 NaN
# 4                    NaN                NaN                 NaN
# ...                  ...                ...                 ...
# 85228                NaN                NaN                 NaN
# 85229                NaN                NaN                 NaN
# 85230                NaN                NaN                 NaN
# 85231                NaN                NaN                 NaN
# 85232                0.0                0.0                 3.0
#
#        SCH_RET_G12_IDEA_F  SCH_RET_G12_504_M  SCH_RET_G12_504_F
# 0                     NaN                NaN                NaN
# 1                     3.0                0.0                0.0
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN                NaN                NaN
# ...                   ...                ...                ...
# 85228                 NaN                NaN                NaN
# 85229                 NaN                NaN                NaN
# 85230                 NaN                NaN                NaN
# 85231                 NaN                NaN                NaN
# 85232                 0.0                0.0                0.0
#
# [85233 rows x 260 columns]

# %%
# Cleaning rows with NAN value
merged_df.dropna(subset=ret_cols.columns,how='all',inplace=True)

# %%
merged_df.shape
# Out:
# (49604, 328)

# %%
# Getting the number of rows with 0 enrollment
merged_df[merged_df['MEMBER'] == 0].shape
# Out:
# (35, 328)

# %%
# Removing rows with 0 enrollment value
df_cleaned = merged_df[merged_df['MEMBER'] != 0]

# %%
# Renaming Columns in cleaned dataframe
df_cleaned.rename(columns = {'NCESSCH': 'NCES_SCH_ID',
                             'CHARTER_TEXT':'CHARTER',
                             'MAGNET_TEXT': 'MAGNET',
                             'SCHOOL_TYPE_TEXT': 'SCHOOL_TYPE',
                             'ULOCALE': 'LOCAL_CODE',
                             'TOTFRL': 'TOT_FREE_LUNCH',
                             'MEMBER': 'TOT_ENROLL',
                             'FTE': 'TOT_TEACHERS',
                             'STUTERATIO': 'STU_TEA_RATIO'                           
                            }, inplace = True)

# %%
#Formatting Datatype for string columns
non_num_cols = ['CHARTER','MAGNET','VIRTUAL','SCHOOL_LEVEL',
               'STITLEI','SCHOOL_TYPE','LOCAL_CODE','LEA_STATE_NAME']
df_cleaned[non_num_cols] = df_cleaned[non_num_cols].astype(str)

# %%
# Use regex to extract the part after "-" and before ':' 
df_cleaned['LOCAL_CATEGORY'] = df_cleaned['LOCAL_CODE'].str.extract(r'-(.*?):') # keep the part within ()

# %%
# Removing LOCAL_CODE as we already got category
df_cleaned.drop(columns=['LOCAL_CODE'], inplace=True)

# %%
# Filtering only Elementary, Middle and High school data
cat_to_keep = ['Elementary','Middle','High']
df_cleaned = df_cleaned[df_cleaned['SCHOOL_LEVEL'].isin(cat_to_keep)]

# %%
df_cleaned
# Out:
#         NCES_SCH_ID CHARTER MAGNET      VIRTUAL SCHOOL_LEVEL STITLEI
# 0       10000500870      No     No  Not Virtual       Middle   1-Yes  \
# 1       10000500871      No     No  Not Virtual         High   1-Yes
# 3       10000500889      No     No  Not Virtual   Elementary   1-Yes
# 4       10000501616      No     No  Not Virtual   Elementary   1-Yes
# 5       10000502150      No     No  Not Virtual   Elementary   1-Yes
# ...             ...     ...    ...          ...          ...     ...
# 85228  720003002078      No     No  Not Virtual   Elementary   1-Yes
# 85229  720003002079      No     No  Not Virtual   Elementary   1-Yes
# 85230  720003002082      No     No  Not Virtual       Middle   1-Yes
# 85231  720003002084      No     No  Not Virtual   Elementary   1-Yes
# 85232  720003002085      No     No  Not Virtual         High   1-Yes
#
#           SCHOOL_TYPE  TOT_FREE_LUNCH     KG    G01  ...  SCH_RET_G12_TR_F
# 0      Regular school           332.0    NaN    NaN  ...               NaN  \
# 1      Regular school           456.0    NaN    NaN  ...               0.0
# 3      Regular school           397.0    NaN    NaN  ...               NaN
# 4      Regular school           181.0  443.0    NaN  ...               NaN
# 5      Regular school           422.0    NaN  480.0  ...               NaN
# ...               ...             ...    ...    ...  ...               ...
# 85228  Regular school           145.0   25.0   23.0  ...               NaN
# 85229  Regular school           301.0   46.0   51.0  ...               NaN
# 85230  Regular school           246.0    NaN    NaN  ...               NaN
# 85231  Regular school           104.0   11.0   16.0  ...               NaN
# 85232  Regular school           465.0    NaN    NaN  ...               0.0
#
#        TOT_RET_G12_M  TOT_RET_G12_F  SCH_RET_G12_LEP_M  SCH_RET_G12_LEP_F
# 0                NaN            NaN                NaN                NaN  \
# 1                8.0            4.0                2.0                0.0
# 3                NaN            NaN                NaN                NaN
# 4                NaN            NaN                NaN                NaN
# 5                NaN            NaN                NaN                NaN
# ...              ...            ...                ...                ...
# 85228            NaN            NaN                NaN                NaN
# 85229            NaN            NaN                NaN                NaN
# 85230            NaN            NaN                NaN                NaN
# 85231            NaN            NaN                NaN                NaN
# 85232            9.0            7.0                0.0                0.0
#
#        SCH_RET_G12_IDEA_M  SCH_RET_G12_IDEA_F  SCH_RET_G12_504_M
# 0                     NaN                 NaN                NaN  \
# 1                     5.0                 3.0                0.0
# 3                     NaN                 NaN                NaN
# 4                     NaN                 NaN                NaN
# 5                     NaN                 NaN                NaN
# ...                   ...                 ...                ...
# 85228                 NaN                 NaN                NaN
# 85229                 NaN                 NaN                NaN
# 85230                 NaN                 NaN                NaN
# 85231                 NaN                 NaN                NaN
# 85232                 3.0                 0.0                0.0
#
#        SCH_RET_G12_504_F  LOCAL_CATEGORY
# 0                    NaN            Town
# 1                    0.0            Town
# 3                    NaN            Town
# 4                    NaN            Town
# 5                    NaN            Town
# ...                  ...             ...
# 85228                NaN          Suburb
# 85229                NaN          Suburb
# 85230                NaN          Suburb
# 85231                NaN            City
# 85232                0.0          Suburb
#
# [47657 rows x 328 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=edfebf59-8cf0-4b7e-b1cf-d80b21ef0191' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
